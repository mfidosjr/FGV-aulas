# %% [markdown]
# # Prevenção à Lavagem de Dinheiro (AML) — Detecção de Anomalias com Autoencoder
#
# **1. Contexto de negócio**
#
# Bancos são obrigados por lei a monitorar transações em busca de indícios de lavagem de dinheiro. O desafio prático é que:
#
# - Praticamente não existem exemplos rotulados de "lavagem confirmada" em volume suficiente para treinar um classificador supervisionado tradicional.
# - Os padrões usados por criminosos mudam constantemente — um modelo treinado para reconhecer *fraudes conhecidas* não generaliza para *esquemas novos*.
# - O que os times de compliance realmente querem é: "esta transação foge do padrão normal desse cliente e do padrão normal da base?"
#
# Isso torna o problema mais próximo de **detecção de anomalias não supervisionada** do que de classificação binária. Neste notebook vamos comparar duas abordagens:
#
# 1. Uma regra estatística simples baseada em **z-score por variável**.
# 2. Um **autoencoder** (rede neural) treinado apenas com transações normais, que aprende a "reconstruir" o padrão típico multivariado do cliente.
#
# Todos os dados aqui são **simulados** — não usamos nenhuma base real de transações.

# %% [markdown]
# **Limitações deste notebook**
#
# Antes de seguir, vale deixar claro o que este notebook **não** representa:
#
# - Os padrões de transação usados aqui são 100% **simulados**. Lavagem de dinheiro real envolve redes complexas de contas e pessoas jurídicas, múltiplas jurisdições e técnicas adversariais que evoluem justamente para escapar da detecção — nada disso está representado neste dataset simplificado de 4 variáveis numéricas.
# - Um sistema real de AML combina múltiplos modelos, regras regulatórias específicas (no Brasil, por exemplo, as exigências do COAF) e revisão humana. Não é uma decisão binária automática de um único modelo como os que treinamos aqui.
# - Mais adiante, a validação com múltiplas seeds mostra que o baseline de z-score é bem mais estável entre execuções do que o autoencoder — que, numa das seeds, chegou a colapsar (recall muito baixo). Isso reforça que um modelo mais complexo não é automaticamente mais confiável, especialmente treinado com poucos dados simulados.

# %% [markdown]
# **2. Por que um autoencoder ajuda aqui**
#
# Uma regra de z-score olha para **cada variável isoladamente**: ela sinaliza uma transação se *alguma* variável, sozinha, estiver muito distante da média. Isso funciona bem quando a anomalia é um valor extremo em uma única dimensão.
#
# O problema é que esquemas de lavagem frequentemente aparecem como uma **combinação atípica de variáveis que, individualmente, não são tão extremas assim** — por exemplo, um valor moderadamente alto *e* um número de países envolvidos moderadamente alto *ao mesmo tempo*, quebrando a correlação que normalmente existe entre essas variáveis.
#
# Um autoencoder é treinado para comprimir e reconstruir o **padrão conjunto** das variáveis de uma transação normal. Quando ele recebe uma transação cuja combinação de valores nunca foi vista durante o treino (mesmo que cada valor isolado pareça razoável), o erro de reconstrução tende a ser maior — e é esse erro que usamos como sinal de anomalia.
#
# Vale um aviso desde já: essa vantagem teórica só se traduz em resultado melhor na prática quando a anomalia realmente não aparece nas distribuições individuais das variáveis. Vamos comparar as duas abordagens de forma honesta ao final e discutir o que os números realmente mostraram.

# %% [markdown]
# **0. Instalação de dependências**
#
# Este notebook usa `numpy`, `pandas`, `scikit-learn`, `matplotlib` e `tensorflow`. Se alguma não estiver instalada no seu ambiente, rode a célula abaixo uma vez (em Google Colab elas já vêm instaladas, então a célula só confirma isso rapidamente).

# %%
# %pip install -q numpy pandas scikit-learn matplotlib tensorflow
print('Dependencias OK.')
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 26.2.1
# [notice] To update, run: /Users/marcofidos/fgv-aulas-env/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Dependencias OK.

# %%
import os
os.environ['PYTHONHASHSEED'] = '42'
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

np.random.seed(42)
tf.keras.utils.set_random_seed(42)
tf.config.experimental.enable_op_determinism()
tf.config.threading.set_intra_op_parallelism_threads(1)
tf.config.threading.set_inter_op_parallelism_threads(1)

pd.set_option('display.float_format', lambda x: f'{x:,.2f}')

# %% [markdown]
# **3. Geração do dataset simulado — transações normais**
#
# Vamos gerar ~2.000 transações "normais" com 4 variáveis numéricas:
#
# - `valor`: valor da transação (distribuição log-normal, valores tipicamente na casa das centenas/milhares).
# - `numero_transacoes_dia`: quantas transações esse cliente fez no mesmo dia.
# - `numero_paises_envolvidos`: quantos países aparecem na cadeia da transação (quase sempre 1, raramente 2).
# - `razao_valor_media_historica_cliente`: razão entre o valor da transação e a média histórica do próprio cliente (perto de 1.0 quando o comportamento é típico).
#
# Para dar correlações realistas entre as variáveis, geramos 4 variáveis latentes gaussianas correlacionadas e depois transformamos cada uma na escala da variável de negócio correspondente.

# %%
n_normal = 2000

# matriz de correlação das variáveis latentes (ordem: valor, transacoes_dia, paises, razao)
cov_normal = np.array([
    [1.00, 0.10, 0.10, 0.50],
    [0.10, 1.00, 0.30, 0.10],
    [0.10, 0.30, 1.00, 0.10],
    [0.50, 0.10, 0.10, 1.00],
])

latent_normal = np.random.multivariate_normal(mean=np.zeros(4), cov=cov_normal, size=n_normal)

valor_normal = np.exp(6.5 + 0.5 * latent_normal[:, 0])
transacoes_normal = np.clip(np.round(3 + 1.5 * latent_normal[:, 1]), 1, None)
paises_normal = np.clip(np.round(1.2 + 0.5 * latent_normal[:, 2]), 1, None)
razao_normal = np.clip(1.0 + 0.25 * latent_normal[:, 3], 0.1, None)

df_normal = pd.DataFrame({
    'valor': valor_normal,
    'numero_transacoes_dia': transacoes_normal,
    'numero_paises_envolvidos': paises_normal,
    'razao_valor_media_historica_cliente': razao_normal,
})
df_normal['anomalo'] = 0

df_normal.describe()
# Out:
#          valor  numero_transacoes_dia  numero_paises_envolvidos  \
# count 2,000.00               2,000.00                  2,000.00
# mean    744.45                   3.08                      1.28
# std     409.31                   1.42                      0.45
# min     126.20                   1.00                      1.00
# 25%     463.03                   2.00                      1.00
# 50%     639.89                   3.00                      1.00
# 75%     923.29                   4.00                      2.00
# max   4,150.68                   7.00                      3.00
#
#        razao_valor_media_historica_cliente  anomalo
# count                             2,000.00 2,000.00
# mean                                  0.99     0.00
# std                                   0.25     0.00
# min                                   0.17     0.00
# 25%                                   0.82     0.00
# 50%                                   0.99     0.00
# 75%                                   1.16     0.00
# max                                   1.75     0.00

# %% [markdown]
# **4. Injeção de transações anômalas**
#
# Agora criamos um pequeno grupo (~4% do total) de transações "atípicas". A ideia central é que elas não sejam absurdamente extremas em nenhuma variável isolada, mas sim **combinações incomuns**: valor moderadamente elevado ocorrendo *junto* com um número de países envolvidos moderadamente elevado — uma correlação que praticamente não existe nas transações normais (correlação de 0.10 lá em cima) mas que forçamos a existir aqui (correlação de 0.60).

# %%
n_anom = 90  # ~4.3% do total (2000 normais + 90 anomalas)

cov_anom = np.array([
    [1.00, 0.10, 0.60, 0.50],
    [0.10, 1.00, 0.30, 0.10],
    [0.60, 0.30, 1.00, 0.10],
    [0.50, 0.10, 0.10, 1.00],
])

latent_anom = np.random.multivariate_normal(mean=np.zeros(4), cov=cov_anom, size=n_anom)

# deslocamos as médias de valor e numero_paises para um regime moderadamente mais alto,
# mas mantendo a MESMA escala de variação -- a anomalia está na combinação, não no extremo isolado
valor_anom = np.exp(6.5 + 0.5 * (latent_anom[:, 0] + 1.3))
transacoes_anom = np.clip(np.round(3 + 1.5 * latent_anom[:, 1]), 1, None)
paises_anom = np.clip(np.round(1.2 + 0.5 * (latent_anom[:, 2] + 2.6)), 1, None)
razao_anom = np.clip(1.0 + 0.25 * (latent_anom[:, 3] + 1.3), 0.1, None)

df_anom = pd.DataFrame({
    'valor': valor_anom,
    'numero_transacoes_dia': transacoes_anom,
    'numero_paises_envolvidos': paises_anom,
    'razao_valor_media_historica_cliente': razao_anom,
})
df_anom['anomalo'] = 1

df = pd.concat([df_normal, df_anom], ignore_index=True)
df = df.sample(frac=1.0, random_state=42).reset_index(drop=True)

print(f'Total de transacoes: {len(df)}')
print(f'Transacoes anomalas: {df["anomalo"].sum()} ({100*df["anomalo"].mean():.1f}%)')
df.groupby('anomalo')[['valor', 'numero_transacoes_dia', 'numero_paises_envolvidos', 'razao_valor_media_historica_cliente']].mean()
# Out:
# Total de transacoes: 2090
# Transacoes anomalas: 90 (4.3%)
#            valor  numero_transacoes_dia  numero_paises_envolvidos  \
# anomalo
# 0         744.45                   3.08                      1.28
# 1       1,698.08                   3.10                      2.63
#
#          razao_valor_media_historica_cliente
# anomalo
# 0                                       0.99
# 1                                       1.38

# %% [markdown]
# **5. Separação treino/teste**
#
# Como estamos fazendo detecção de anomalias **não supervisionada**, o autoencoder só pode ser treinado com transações consideradas normais (é assim que ele aprende "o que é normal"). Fazemos o seguinte split:
#
# - **Treino**: 80% das transações normais (usadas para calibrar tanto o z-score quanto o autoencoder).
# - **Teste**: os 20% de normais restantes + **todas** as transações anômalas (usado apenas para avaliação — nenhum dos dois métodos "vê" esses rótulos durante o ajuste).

# %%
features = ['valor', 'numero_transacoes_dia', 'numero_paises_envolvidos', 'razao_valor_media_historica_cliente']

df_normal_only = df[df['anomalo'] == 0].reset_index(drop=True)
df_anom_only = df[df['anomalo'] == 1].reset_index(drop=True)

treino_normal, teste_normal = train_test_split(df_normal_only, test_size=0.2, random_state=42)

teste = pd.concat([teste_normal, df_anom_only], ignore_index=True)
teste = teste.sample(frac=1.0, random_state=42).reset_index(drop=True)

X_treino = treino_normal[features].values
X_teste = teste[features].values
y_teste = teste['anomalo'].values

print(f'Treino (somente normais): {len(X_treino)} transacoes')
print(f'Teste (normais + anomalas): {len(X_teste)} transacoes, sendo {y_teste.sum()} anomalas')
# Out:
# Treino (somente normais): 1600 transacoes
# Teste (normais + anomalas): 490 transacoes, sendo 90 anomalas

# %% [markdown]
# **6. Baseline: regra de z-score por variável**
#
# A regra clássica de compliance: calcular a média e o desvio-padrão de cada variável **usando apenas o conjunto de treino (normal)** e marcar como suspeita qualquer transação em que **pelo menos uma** variável esteja a mais de `N` desvios-padrão da média.

# %%
medias_treino = X_treino.mean(axis=0)
desvios_treino = X_treino.std(axis=0)

def zscore_flags(X, N):
    z = np.abs((X - medias_treino) / desvios_treino)
    return (z > N).any(axis=1)

# taxa de falso positivo (FPR) e recall variando o limiar N, para depois comparar com o autoencoder
resultados_zscore = []
for N in np.arange(1.5, 5.01, 0.05):
    pred = zscore_flags(X_teste, N).astype(int)
    fpr = pred[y_teste == 0].mean()
    recall = recall_score(y_teste, pred, zero_division=0)
    resultados_zscore.append((N, fpr, recall))

resultados_zscore = pd.DataFrame(resultados_zscore, columns=['N', 'fpr', 'recall'])
resultados_zscore.iloc[::10]
# Out:
#       N  fpr  recall
# 0  1.50 0.45    0.99
# 10 2.00 0.16    0.76
# 20 2.50 0.06    0.68
# 30 3.00 0.02    0.64
# 40 3.50 0.01    0.61
# 50 4.00 0.01    0.18
# 60 4.50 0.01    0.18
# 70 5.00 0.00    0.14

# %% [markdown]
# **7. Modelo de rede neural: Autoencoder**
#
# O autoencoder é uma rede neural pequena que aprende a **comprimir** as 4 variáveis em uma representação de dimensão menor e depois **reconstruí-las**. Ele é treinado apenas com transações normais — então aprende bem o padrão típico. Quando recebe uma transação cuja combinação de valores é incomum, a reconstrução tende a errar mais.
#
# Passos:
# 1. Padronizar as variáveis (média 0, desvio 1) usando estatísticas do treino.
# 2. Treinar o autoencoder (`Dense` reduzindo para 2 neurônios no meio e depois reconstruindo as 4 variáveis originais).
# 3. Calcular o erro de reconstrução (MSE) em cada transação de teste.
# 4. Definir o limiar como o percentil 95 do erro de reconstrução **nas transações de treino** (normais) e marcar como suspeita qualquer transação de teste com erro acima desse limiar.

# %%
media_padrao = X_treino.mean(axis=0)
desvio_padrao = X_treino.std(axis=0)

X_treino_std = (X_treino - media_padrao) / desvio_padrao
X_teste_std = (X_teste - media_padrao) / desvio_padrao

n_features = X_treino_std.shape[1]

autoencoder = keras.Sequential([
    layers.Input(shape=(n_features,)),
    layers.Dense(3, activation='relu'),
    layers.Dense(2, activation='relu'),
    layers.Dense(3, activation='relu'),
    layers.Dense(n_features, activation='linear'),
])

autoencoder.compile(optimizer='adam', loss='mse')

historico = autoencoder.fit(
    X_treino_std, X_treino_std,
    epochs=80,
    batch_size=32,
    validation_split=0.1,
    verbose=0,
)

print(f'Loss final (treino): {historico.history["loss"][-1]:.4f}')
print(f'Loss final (validacao): {historico.history["val_loss"][-1]:.4f}')
# Out:
# Loss final (treino): 0.3402
# Loss final (validacao): 0.3612

# %%
reconstrucao_treino = autoencoder.predict(X_treino_std, verbose=0)
erro_treino = np.mean((X_treino_std - reconstrucao_treino) ** 2, axis=1)

reconstrucao_teste = autoencoder.predict(X_teste_std, verbose=0)
erro_teste = np.mean((X_teste_std - reconstrucao_teste) ** 2, axis=1)

limiar_ae = np.percentile(erro_treino, 95)
pred_ae = (erro_teste > limiar_ae).astype(int)

fpr_ae = pred_ae[y_teste == 0].mean()
recall_ae = recall_score(y_teste, pred_ae, zero_division=0)

print(f'Limiar do autoencoder (percentil 95 do erro no treino): {limiar_ae:.4f}')
print(f'Taxa de falso positivo (FPR) no teste: {fpr_ae:.3f}')
print(f'Recall no teste: {recall_ae:.3f}')
# Out:
# Limiar do autoencoder (percentil 95 do erro no treino): 1.1473
# Taxa de falso positivo (FPR) no teste: 0.055
# Recall no teste: 0.633
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1787242641.302177 32533299 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}

# %% [markdown]
# **8. Comparação lado a lado**
#
# Para comparar de forma justa, buscamos o limiar `N` do z-score que produz uma taxa de falso positivo **o mais próxima possível** da taxa de falso positivo do autoencoder — e comparamos o recall de cada abordagem nesse ponto.

# %%
idx_mais_proximo = (resultados_zscore['fpr'] - fpr_ae).abs().idxmin()
linha_zscore = resultados_zscore.loc[idx_mais_proximo]

comparacao = pd.DataFrame([
    {
        'metodo': 'Z-score por variavel',
        'limiar': f"N = {linha_zscore['N']:.2f}",
        'fpr_teste': linha_zscore['fpr'],
        'recall_teste': linha_zscore['recall'],
    },
    {
        'metodo': 'Autoencoder',
        'limiar': f'percentil 95 do erro (treino) = {limiar_ae:.4f}',
        'fpr_teste': fpr_ae,
        'recall_teste': recall_ae,
    },
])

comparacao
# Out:
#                  metodo                                  limiar  fpr_teste  \
# 0  Z-score por variavel                                N = 2.60       0.06
# 1           Autoencoder  percentil 95 do erro (treino) = 1.1473       0.06
#
#    recall_teste
# 0          0.67
# 1          0.63

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

axes[0].scatter(range(len(erro_teste)), erro_teste, c=y_teste, cmap='coolwarm', s=15, alpha=0.7)
axes[0].axhline(limiar_ae, color='black', linestyle='--', label='limiar (percentil 95 treino)')
axes[0].set_title('Erro de reconstrucao do autoencoder no teste')
axes[0].set_xlabel('indice da transacao')
axes[0].set_ylabel('erro de reconstrucao (MSE)')
axes[0].legend()

axes[1].bar(comparacao['metodo'], comparacao['recall_teste'], color=['#4c72b0', '#55a868'])
axes[1].set_title(f'Recall comparado (FPR similar, ~{fpr_ae:.1%})')
axes[1].set_ylabel('recall (transacoes anomalas capturadas)')
axes[1].set_ylim(0, 1)

plt.tight_layout()
plt.show()

# %% [markdown]
# **Lendo o gráfico da direita: recall com FPR equalizada**
#
# O gráfico de barras à direita responde a uma pergunta simples: se os dois métodos soarem o alarme com a mesma frequência de falsos positivos (aqui, ~6% das transações normais são erroneamente sinalizadas), qual deles captura mais das transações que são de fato lavagem de dinheiro?
#
# Essa é a comparação "justa" entre os métodos: sem equalizar o FPR, seria fácil enganar a comparação simplesmente tornando um dos métodos mais "sensível" (mais alarmes, mais recall, mas também mais falso positivo, o que sobrecarrega a equipe de compliance). Ao fixar o FPR e comparar o recall, isolamos a pergunta que interessa: para o mesmo custo operacional de investigar falsos alarmes, qual método entrega mais casos reais de lavagem de dinheiro?
#
# **Veredito, com os números deste notebook:** o z-score simples teve recall ≈0,67, ligeiramente acima do autoencoder (≈0,63) — ou seja, aqui a regra univariada mais simples se saiu melhor que a rede neural. Isso é plausível: a vantagem teórica do autoencoder só se manifesta quando a anomalia é invisível ao se olhar cada variável isoladamente (uma combinação atípica de valores individualmente normais). Neste dataset simulado, parte do sinal de anomalia "vazou" para as distribuições marginais de cada variável — e nesse regime um teste univariado como o z-score já captura boa parte do sinal, sem precisar da capacidade extra do autoencoder de modelar correlações entre variáveis.

# %% [markdown]
# **9. Conclusão**
#
# Ao rodar este notebook, com as duas abordagens calibradas para uma taxa de falso positivo parecida (~6%), obtivemos:
#
# - **Z-score por variável**: recall de ~0,67 (capturou cerca de 67% das transações realmente anômalas).
# - **Autoencoder**: recall de ~0,63 (capturou cerca de 63%).
#
# Ou seja, **neste cenário simulado específico, a regra simples de z-score se saiu ligeiramente melhor** que a rede neural — e isso é uma lição importante, não um erro do experimento. A razão provável: para deslocar o número de países envolvidos de forma consistente nas transações anômalas, também precisamos deslocar sua distribuição individual (não é possível ter países=4 sem que isso já seja, sozinho, um valor raro face à distribuição normal). Como parte do sinal de anomalia "vazou" para as distribuições marginais, uma regra univariada consegue capturar boa parte dele diretamente.
#
# O ponto pedagógico central não é "rede neural sempre vence" — é que:
#
# - **Redes neurais não são bala de prata.** A vantagem teórica do autoencoder (capturar combinações atípicas de variáveis que, isoladamente, parecem normais) só se materializa quando a anomalia realmente não deixa rastro nas distribuições marginais. Vale a pena testar empiricamente, caso a caso, se a complexidade extra se paga.
# - Uma regra de z-score é simples, barata, rápida de calibrar e fácil de explicar para auditoria e reguladores — vantagens que pesam muito em compliance.
# - Na prática, bancos usam múltiplas camadas: regras simples para triagem inicial e barata, modelos de anomalia mais sofisticados (autoencoders, isolation forests, etc.) para capturar padrões que as regras simples não veem, e sempre um analista humano revisando os casos sinalizados antes de qualquer reporte regulatório.
# - Nenhum modelo de anomalia substitui o julgamento humano em AML: o papel de qualquer um desses modelos é **priorizar** quais transações merecem revisão manual, reduzindo o volume que a equipe de compliance precisa investigar — e a escolha do modelo certo depende de testar contra o padrão real de anomalias que se quer capturar.

# %% [markdown]
# **Validação com múltiplas seeds**
#
# A conclusão acima (`z-score` ≈0,67 vs. autoencoder ≈0,63) vem de uma única seed (42). Isso é uma amostra de tamanho 1 — não sabemos se essa diferença é um padrão real ou apenas ruído da inicialização aleatória da rede e do sorteio específico dos dados simulados.
#
# Para checar isso, repetimos o **pipeline inteiro do zero** — geração dos dados normais e anômalos, split treino/teste, calibração do z-score e reconstrução completa do autoencoder (pesos re-inicializados) — para três seeds diferentes: `42` (a mesma do walkthrough acima, como checagem de sanidade), `7` e `123`. Reaproveitamos o mesmo padrão de determinismo já usado no notebook (`tf.keras.utils.set_random_seed`, `tf.config.experimental.enable_op_determinism`, threads intra/inter-op fixadas em 1), aplicando-o a cada seed antes de gerar os dados e treinar o autoencoder correspondente.

# %%
def rodar_pipeline_seed(seed):
    """Reproduz do zero, para uma dada seed, todo o pipeline deste notebook:
    geracao dos dados simulados (normais + anomalos), split treino/teste,
    baseline de z-score e um autoencoder reconstruido e retreinado do zero.
    Retorna o recall de cada abordagem no ponto de FPR equalizada."""

    # -- mesmo padrao de determinismo usado no restante do notebook --
    np.random.seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()
    tf.config.threading.set_intra_op_parallelism_threads(1)
    tf.config.threading.set_inter_op_parallelism_threads(1)

    # -- geracao das transacoes normais (mesmos parametros da secao 3) --
    n_normal = 2000
    cov_normal = np.array([
        [1.00, 0.10, 0.10, 0.50],
        [0.10, 1.00, 0.30, 0.10],
        [0.10, 0.30, 1.00, 0.10],
        [0.50, 0.10, 0.10, 1.00],
    ])
    latent_normal = np.random.multivariate_normal(mean=np.zeros(4), cov=cov_normal, size=n_normal)
    valor_normal = np.exp(6.5 + 0.5 * latent_normal[:, 0])
    transacoes_normal = np.clip(np.round(3 + 1.5 * latent_normal[:, 1]), 1, None)
    paises_normal = np.clip(np.round(1.2 + 0.5 * latent_normal[:, 2]), 1, None)
    razao_normal = np.clip(1.0 + 0.25 * latent_normal[:, 3], 0.1, None)

    df_normal_s = pd.DataFrame({
        'valor': valor_normal,
        'numero_transacoes_dia': transacoes_normal,
        'numero_paises_envolvidos': paises_normal,
        'razao_valor_media_historica_cliente': razao_normal,
    })
    df_normal_s['anomalo'] = 0

    # -- injecao das transacoes anomalas (mesmos parametros da secao 4) --
    n_anom = 90
    cov_anom = np.array([
        [1.00, 0.10, 0.60, 0.50],
        [0.10, 1.00, 0.30, 0.10],
        [0.60, 0.30, 1.00, 0.10],
        [0.50, 0.10, 0.10, 1.00],
    ])
    latent_anom = np.random.multivariate_normal(mean=np.zeros(4), cov=cov_anom, size=n_anom)
    valor_anom = np.exp(6.5 + 0.5 * (latent_anom[:, 0] + 1.3))
    transacoes_anom = np.clip(np.round(3 + 1.5 * latent_anom[:, 1]), 1, None)
    paises_anom = np.clip(np.round(1.2 + 0.5 * (latent_anom[:, 2] + 2.6)), 1, None)
    razao_anom = np.clip(1.0 + 0.25 * (latent_anom[:, 3] + 1.3), 0.1, None)

    df_anom_s = pd.DataFrame({
        'valor': valor_anom,
        'numero_transacoes_dia': transacoes_anom,
        'numero_paises_envolvidos': paises_anom,
        'razao_valor_media_historica_cliente': razao_anom,
    })
    df_anom_s['anomalo'] = 1

    df_s = pd.concat([df_normal_s, df_anom_s], ignore_index=True)
    df_s = df_s.sample(frac=1.0, random_state=seed).reset_index(drop=True)

    # -- split treino/teste (mesma logica da secao 5) --
    df_normal_only_s = df_s[df_s['anomalo'] == 0].reset_index(drop=True)
    df_anom_only_s = df_s[df_s['anomalo'] == 1].reset_index(drop=True)

    treino_normal_s, teste_normal_s = train_test_split(df_normal_only_s, test_size=0.2, random_state=seed)
    teste_s = pd.concat([teste_normal_s, df_anom_only_s], ignore_index=True)
    teste_s = teste_s.sample(frac=1.0, random_state=seed).reset_index(drop=True)

    X_treino_s = treino_normal_s[features].values
    X_teste_s = teste_s[features].values
    y_teste_s = teste_s['anomalo'].values

    # -- baseline de z-score (mesma logica da secao 6) --
    medias_treino_s = X_treino_s.mean(axis=0)
    desvios_treino_s = X_treino_s.std(axis=0)

    def zscore_flags_s(X, N):
        z = np.abs((X - medias_treino_s) / desvios_treino_s)
        return (z > N).any(axis=1)

    resultados_zscore_s = []
    for N in np.arange(1.5, 5.01, 0.05):
        pred = zscore_flags_s(X_teste_s, N).astype(int)
        fpr = pred[y_teste_s == 0].mean()
        recall = recall_score(y_teste_s, pred, zero_division=0)
        resultados_zscore_s.append((N, fpr, recall))
    resultados_zscore_s = pd.DataFrame(resultados_zscore_s, columns=['N', 'fpr', 'recall'])

    # -- autoencoder reconstruido e retreinado do zero (mesma arquitetura da secao 7) --
    media_padrao_s = X_treino_s.mean(axis=0)
    desvio_padrao_s = X_treino_s.std(axis=0)
    X_treino_std_s = (X_treino_s - media_padrao_s) / desvio_padrao_s
    X_teste_std_s = (X_teste_s - media_padrao_s) / desvio_padrao_s
    n_features_s = X_treino_std_s.shape[1]

    keras.backend.clear_session()
    autoencoder_s = keras.Sequential([
        layers.Input(shape=(n_features_s,)),
        layers.Dense(3, activation='relu'),
        layers.Dense(2, activation='relu'),
        layers.Dense(3, activation='relu'),
        layers.Dense(n_features_s, activation='linear'),
    ])
    autoencoder_s.compile(optimizer='adam', loss='mse')
    autoencoder_s.fit(
        X_treino_std_s, X_treino_std_s,
        epochs=80,
        batch_size=32,
        validation_split=0.1,
        verbose=0,
    )

    reconstrucao_treino_s = autoencoder_s.predict(X_treino_std_s, verbose=0)
    erro_treino_s = np.mean((X_treino_std_s - reconstrucao_treino_s) ** 2, axis=1)
    reconstrucao_teste_s = autoencoder_s.predict(X_teste_std_s, verbose=0)
    erro_teste_s = np.mean((X_teste_std_s - reconstrucao_teste_s) ** 2, axis=1)

    limiar_ae_s = np.percentile(erro_treino_s, 95)
    pred_ae_s = (erro_teste_s > limiar_ae_s).astype(int)
    fpr_ae_s = pred_ae_s[y_teste_s == 0].mean()
    recall_ae_s = recall_score(y_teste_s, pred_ae_s, zero_division=0)

    # -- zscore no ponto de FPR mais proximo do autoencoder (mesma logica da secao 8) --
    idx_mais_proximo_s = (resultados_zscore_s['fpr'] - fpr_ae_s).abs().idxmin()
    linha_zscore_s = resultados_zscore_s.loc[idx_mais_proximo_s]

    return {
        'seed': seed,
        'fpr_zscore': linha_zscore_s['fpr'],
        'recall_zscore': linha_zscore_s['recall'],
        'fpr_autoencoder': fpr_ae_s,
        'recall_autoencoder': recall_ae_s,
    }


resultados_multiplas_seeds = [rodar_pipeline_seed(seed) for seed in [42, 7, 123]]
df_resultados_seeds = pd.DataFrame(resultados_multiplas_seeds)
df_resultados_seeds
# Out:
# E0000 00:00:1787242646.984152 32533299 node_def_util.cc:682] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_14}}
#    seed  fpr_zscore  recall_zscore  fpr_autoencoder  recall_autoencoder
# 0    42        0.06           0.67             0.06                0.63
# 1     7        0.05           0.53             0.05                0.56
# 2   123        0.06           0.67             0.06                0.13

# %%
resumo_seeds = df_resultados_seeds[['recall_zscore', 'recall_autoencoder']].agg(['mean', 'std']).T
resumo_seeds.columns = ['recall_medio', 'recall_desvio_padrao']
resumo_seeds.index = ['Z-score por variavel', 'Autoencoder']
resumo_seeds
# Out:
#                       recall_medio  recall_desvio_padrao
# Z-score por variavel          0.62                  0.08
# Autoencoder                   0.44                  0.27

# %% [markdown]
# **Resultado honesto das 3 seeds**
#
# Reproduzindo o pipeline inteiro do zero para as seeds 42, 7 e 123 (todas calibradas para FPR ≈5-6%), obtivemos:
#
# | Seed | FPR z-score | Recall z-score | FPR autoencoder | Recall autoencoder |
# |---|---|---|---|---|
# | 42  | 0,055 | 0,667 | 0,055 | 0,633 |
# | 7   | 0,050 | 0,533 | 0,048 | 0,556 |
# | 123 | 0,060 | 0,667 | 0,060 | 0,133 |
#
# **Média ± desvio-padrão do recall nas 3 seeds:**
#
# - **Z-score por variável:** 0,622 ± 0,077
# - **Autoencoder:** 0,441 ± 0,269
#
# A seed 42 (a mesma do walkthrough original) reproduz exatamente os números já reportados (z-score ≈0,67, autoencoder ≈0,63) — o padrão de determinismo funcionou como esperado. Mas ao variar a seed, a conclusão original **não se mantém como estava enunciada**, e o quadro real é pior para o autoencoder do que a seed única sugeria:
#
# - O **z-score é consistentemente melhor ou empatado** com o autoencoder nas 3 seeds (nunca perde), com recall variando pouco (0,53 a 0,67, desvio-padrão de apenas 0,08).
# - O **autoencoder é muito mais instável**: seu recall varia de 0,13 a 0,63 entre seeds (desvio-padrão de 0,27, mais de 3x o do z-score). Na seed 123 ele praticamente **falhou** (recall de 0,13, capturando só ~12 das 90 anomalias, contra 60 do z-score na mesma FPR) — evidência de que, com uma rede desse tamanho e poucos dados, a inicialização aleatória dos pesos pode levar a um mínimo local ruim que compromete a capacidade de generalização do erro de reconstrução.
#
# Ou seja: a lição pedagógica do notebook original — "redes neurais não são bala de prata" — na verdade fica **mais forte**, não mais fraca, ao olhar para múltiplas seeds. Não é apenas que o z-score empata ou vence por uma margem pequena; é que o autoencoder, neste regime de poucos dados e rede pequena, é **menos confiável e mais sensível à sorte da inicialização** do que a regra simples. Isso reforça, na prática, por que times de compliance preferem regras simples e auditáveis como primeira camada, e por que qualquer modelo mais complexo (autoencoder, isolation forest, etc.) precisa ser validado com múltiplas execuções — e não uma única seed "sortuda" — antes de entrar em produção.

# %% [markdown]
# **Anexo: Outras Aplicações de Negócio com a Mesma Técnica**
#
# A técnica usada aqui (autoencoder detectando anomalias sem rótulos, aprendendo apenas o padrão "normal") se aplica a diversos outros problemas de negócio:
#
# ### 1. Cibersegurança
# - **Detecção de Intrusões (IDS):** monitorar tráfego de rede para identificar padrões anômalos que possam indicar um ataque cibernético.
#
# ### 2. Manufatura e Indústria
# - **Controle de Qualidade Automático:** detectar produtos que fogem do padrão "normal" aprendido, mesmo sem exemplos rotulados de defeito.
#
# ### 3. Tecnologia da Informação
# - **Monitoramento de Infraestrutura:** identificar vazamentos de memória (memory leak) ou gargalos a partir de métricas de CPU, memória e tráfego fora do padrão.
# - **Análise de Logs de Erro:** detectar quando um tipo de erro começa a ocorrer com frequência anormal após uma atualização de software.
#
# ### 4. Saúde
# - **Monitoramento de Sinais Vitais:** analisar dados contínuos de pacientes em UTI para detectar desvios sutis do padrão individual do paciente, antes que alarmes tradicionais disparem.

# %% [markdown]
# **Exercício**
#
# 1. **Por que o autoencoder colapsou na seed 123?** A validação com múltiplas seeds mostrou recall de apenas 0,13 na seed 123 (contra 0,63-0,67 nas outras), enquanto o z-score se manteve estável (0,53-0,67) em todas. Investigue essa instabilidade: altere a arquitetura do autoencoder na função `rodar_pipeline_seed` — teste, por exemplo, uma camada latente com mais neurônios (`Dense(3)` no meio em vez de `Dense(2)`) e também uma versão ainda mais estreita, e rode as 3 seeds de novo para cada variante. O colapso desaparece, diminui ou persiste? A instabilidade parece estar ligada ao tamanho do "bottleneck", ao número de épocas de treino, ou a outro fator? Documente o que você observou e uma hipótese para a causa.
#
# 2. **Um ensemble simples ajuda?** Combine as duas abordagens: marque uma transação como suspeita se o z-score **ou** o autoencoder disparar (ao invés de usar cada método isoladamente). Calcule o FPR e o recall desse ensemble no teste (seed 42) e compare com o z-score isolado e o autoencoder isolado nesse mesmo ponto. O ganho de recall (se houver) compensa o aumento no FPR? Repita a comparação para as seeds 7 e 123 — o ensemble ajuda a "cobrir" os casos em que o autoencoder falha, ou o FPR combinado fica alto demais para ser operacionalmente útil em compliance?
